# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("whale_returns.csv")
whale_df = pd.read_csv('./Resources/whale_returns.csv', index_col = 'Date', parse_dates = True, infer_datetime_format= True )


# YOUR CODE HERE

from numpy import nan as NA


whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
# YOUR CODE HERE
whale_df.isnull().sum(axis = 0)
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
whale_df_no_nulls = whale_df.dropna(axis = 0)
whale_df_no_nulls.isnull().sum(axis = 0)
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
# YOUR CODE HERE
#algo_returns_csv = Path("whale_portfolio_analysis/algo_returns.csv")
algo_df = pd.read_csv("./Resources/algo_returns.csv", index_col = 'Date', parse_dates = True, infer_datetime_format= True)

# %%
# Count nulls
# YOUR CODE HERE
algo_df.isnull().sum(axis = 0)
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
# YOUR CODE HERE
algo_df_no_nulls = algo_df.dropna(axis = 0)
algo_df_no_nulls
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("Resources/sp500_history.csv")
#sp500_historical_csv = Path("whale_portfolio_analysis/sp500_history.csv")
# YOUR CODE HERE
sp500_df = pd.read_csv("./Resources/sp500_history.csv", index_col = 'Date', parse_dates = True, infer_datetime_format= True)

# %%
# Check Data Types
# YOUR CODE HERE
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
# YOUR CODE HERE
sp500_df['Close'] = sp500_df['Close'].str.replace(r'$', '')

sp500_no_dollar_df = sp500_df

sp500_no_dollar_df[['Close']] = sp500_no_dollar_df[['Close']].apply(pd.to_numeric)

sp500_no_dollar_df
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06
# ...             ...
# 2012-10-05  1460.93
# 2012-10-04  1461.40
# 2012-10-03  1450.99
# 2012-10-02  1445.75
# 2012-10-01  1444.49
#
# [1649 rows x 1 columns]

# %%
###### Calculate Daily Returns
# YOUR CODE HERE
sp500_ascending_df = sp500_no_dollar_df.sort_values(by ='Date', ascending = True)
sp500_pct_change = sp500_ascending_df.pct_change() 
sp500_pct_change
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1649 rows x 1 columns]

# %%
# Drop nulls
# YOUR CODE HERE
sp500_no_nulls = sp500_pct_change.dropna(axis = 0)
sp500_no_nulls
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
# Rename Column
# YOUR CODE HERE
sp500_rename_close_to_sp500_df = sp500_no_nulls.rename(columns = {'Close' : 'S&P 500'})
sp500_rename_close_to_sp500_df
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
# YOUR CODE HERE
combined_df = pd.concat([whale_df_no_nulls, algo_df_no_nulls, sp500_rename_close_to_sp500_df], axis = 1, join = 'inner')
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?
#
# ## Answer:
#
# In review, of the Daily Returns, we can take away that asa benchmark, the S&P 500, as an index is fairly consistent from a day to day volitility perspective.  In review of the plot, we can infer that Tiger Global Managment tends to have instances where their performance has had greater volity in comparison to the S&P 500. We can also infer that Berkdshire Hathaway, over the same period tends to have silghtly better day to day returns than the S&P 500.  During periods of greater volitily the S&P 500 tends to out perform all portfolios when considering  the downside risk.
#
# From a comulativie returns perspecitve.  We can see that Algo1 and Berkshire Hathaway Inc. have the best performance in relation to the other portfolios and our index (S&P 500).

# %%
# Plot daily returns 
# YOUR CODE HERE
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]
combined_df.plot(title = 'Daily Returns')
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}, xlabel='Date'>

# %%
# Plot cumulative returns
# YOUR CODE HERE
combined_df.cumsum(axis = 0).plot(title = 'Cumulative Returns' )
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# > Algo 1 appears to have an interquartile range slightly with a median slightly above 0.  The range is also tighter that the S&P 500 based on visual analysis of the box and wisker plot.
# 2. Calculate the standard deviation for all portfolios
# >
# 4. Determine which portfolios are riskier than the S&P 500
# >Tiger Global and Berkshire Hathaway demonstrate more volity when you look at the daily standard deviation.  Tiger Global has the most extreme outliers above and below the maximim and minimun.
# 5. Calculate the Annualized Standard Deviation
# >

# %%
# Box plot to visually show risk
# YOUR CODE HERE
combined_df.boxplot()
# Out:
# <AxesSubplot:>

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?
# YOUR CODE HERE

daily_std_portfolios = combined_df.std()
daily_std_portfolios
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
# YOUR CODE HERE

# %%
# Calculate the annualized standard deviation (252 trading days)
# YOUR CODE HERE
annualized_std = daily_std_portfolios*np.sqrt(252)
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500                        0.135786
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
# YOUR CODE HERE

rolling_std = combined_df.rolling(window = 21).std().plot(title = '21 Day Rolling Standard Deviation')

# %%
# Construct a correlation table
correlation_table = combined_df.corr()
correlation_table
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
# YOUR CODE HERE

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
# YOUR CODE HERE

covariance = combined_df['BERKSHIRE HATHAWAY INC'].cov(combined_df['S&P 500'])
variance = combined_df['S&P 500'].var()
berkshire_beta = covariance / variance
rolling_covariance = combined_df['BERKSHIRE HATHAWAY INC'].rolling(window = 30).cov(combined_df['S&P 500'])
rolling_variance = combined_df['S&P 500'].rolling(window = 30).var()

rolling_beta_berkshire = rolling_covariance / rolling_variance
rolling_beta_berkshire.plot(title = 'Rolling 30 Day Beta of Berkshire Hathaway Inc')
#ovariance.plot(figsize=(20,10), title = 'Berkshire Hathaway Inc. Beta')
# Out:
# <AxesSubplot:title={'center':'Rolling 30 Day Beta of Berkshire Hathaway Inc'}, xlabel='Date'>

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
# YOUR CODE HERE
combined_df_ewm = combined_df.ewm(span = 30, adjust = False).std()
combined_df_ewm.plot(title = 'Exponentially Weighted Average')
# Out:
# <AxesSubplot:title={'center':'Exponentially Weighted Average'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
# ## Answer
# > Algo 1 outperfomrs the S%P 500 as well as the other portfolios significantly.  Algo 2 fails to out perform the the S&P 500, Algo 1 and Berkshire Hathaway.

# %%
# Calculate annualized Sharpe Ratios
# YOUR CODE HERE

sharpe_ratios = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE
sharpe_ratios.plot(kind = 'bar', title = "Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
# YOUR CODE HERE
google_historical_csv = Path("goog_historical.csv")
google_df = pd.read_csv('./Resources/goog_historical.csv', index_col = 'Trade DATE', parse_dates = True, infer_datetime_format= True )
google_datefirst_df = google_df[['Symbol', 'NOCP']].sort_values(by = 'Trade DATE', ascending = True)
google_datefirst_df.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
# Read the second stock
# YOUR CODE HERE

aapl_historical_csv = Path("aapl_historical.csv")
aapl_df = pd.read_csv('./Resources/aapl_historical.csv', index_col = 'Trade DATE', parse_dates = True, infer_datetime_format= True )
aapl_datefirst_df = aapl_df[['Symbol', 'NOCP']].sort_values(by = 'Trade DATE', ascending = True)
aapl_datefirst_df
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59
# 2018-05-14   AAPL  188.15
# 2018-05-15   AAPL  186.44
# 2018-05-16   AAPL  188.18
# 2018-05-17   AAPL  186.99
# ...           ...     ...
# 2019-05-03   AAPL  211.75
# 2019-05-06   AAPL  208.48
# 2019-05-07   AAPL  202.86
# 2019-05-08   AAPL  202.90
# 2019-05-09   AAPL  200.72
#
# [250 rows x 2 columns]

# %%
# Read the third stock
# YOUR CODE HERE

cost_historical_csv = Path("cost_historical.csv")
cost_df = pd.read_csv('./Resources/cost_historical.csv', index_col = 'Trade DATE', parse_dates = True, infer_datetime_format= True )
cost_datefirst_df = cost_df[['Symbol', 'NOCP']].sort_values(by = 'Trade DATE', ascending = True)
cost_datefirst_df
# Out:
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   COST  195.76
# 2018-05-14   COST  195.88
# 2018-05-15   COST  195.48
# 2018-05-16   COST  198.71
# 2018-05-17   COST  199.60
# ...           ...     ...
# 2019-05-03   COST  244.62
# 2019-05-06   COST  244.23
# 2019-05-07   COST  240.18
# 2019-05-08   COST  241.34
# 2019-05-09   COST  243.47
#
# [250 rows x 2 columns]

# %%
# Concatenate all stocks into a single DataFrame
# YOUR CODE HERE
my_portfolio_df = pd.concat([google_datefirst_df, aapl_datefirst_df, cost_datefirst_df], axis = 0, join = 'inner')
my_portfolio_df
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59
# ...           ...      ...
# 2019-05-03   COST   244.62
# 2019-05-06   COST   244.23
# 2019-05-07   COST   240.18
# 2019-05-08   COST   241.34
# 2019-05-09   COST   243.47
#
# [750 rows x 2 columns]

# %%
# Reset the index
# YOUR CODE HERE
my_portfolio_index_reset_df = my_portfolio_df.reset_index()
my_portfolio_index_reset_df
# Out:
#     Trade DATE Symbol     NOCP
# 0   2018-05-11   GOOG  1098.26
# 1   2018-05-14   GOOG  1100.20
# 2   2018-05-15   GOOG  1079.23
# 3   2018-05-16   GOOG  1081.77
# 4   2018-05-17   GOOG  1078.59
# ..         ...    ...      ...
# 745 2019-05-03   COST   244.62
# 746 2019-05-06   COST   244.23
# 747 2019-05-07   COST   240.18
# 748 2019-05-08   COST   241.34
# 749 2019-05-09   COST   243.47
#
# [750 rows x 3 columns]

# %%
# Pivot so that each column of prices represents a unique symbol
# YOUR CODE HERE

my_portfolio_grouped_ticker = my_portfolio_index_reset_df.pivot(index = 'Trade DATE' , columns = 'Symbol' )
print(my_portfolio_grouped_ticker)
# Out:
#               NOCP
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59
# ...            ...     ...      ...
# 2019-05-03  211.75  244.62  1185.40
# 2019-05-06  208.48  244.23  1189.39
# 2019-05-07  202.86  240.18  1174.10
# 2019-05-08  202.90  241.34  1166.27
# 2019-05-09  200.72  243.47  1162.38
#
# [250 rows x 3 columns]

# %%
# Drop Nulls
# YOUR CODE HERE

my_portfolio_daily_returns = my_portfolio_grouped_ticker.pct_change() 

my_portfolio_no_nulls = my_portfolio_daily_returns.dropna(axis = 0)
my_portfolio_no_nulls.isnull().sum(axis = 0)
# Out:
#       Symbol
# NOCP  AAPL      0
#       COST      0
#       GOOG      0
# dtype: int64

# %%
## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
# YOUR CODE HERE
my_port_returns = my_portfolio_no_nulls.dot(weights)
my_port_returns
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
#                 ...
# 2019-05-03    0.013329
# 2019-05-06   -0.004557
# 2019-05-07   -0.018798
# 2019-05-08   -0.000547
# 2019-05-09   -0.001751
# Length: 249, dtype: float64

# %%
my_port_returns_df = pd.DataFrame(my_port_returns, columns = ['My Portfolio'])
my_port_returns_df
# Out:
#             My Portfolio
# Trade DATE
# 2018-05-14      0.000015
# 2018-05-15     -0.010064
# 2018-05-16      0.009403
# 2018-05-17     -0.001595
# 2018-05-18     -0.006061
# ...                  ...
# 2019-05-03      0.013329
# 2019-05-06     -0.004557
# 2019-05-07     -0.018798
# 2019-05-08     -0.000547
# 2019-05-09     -0.001751
#
# [249 rows x 1 columns]

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
# YOUR CODE HERE

combined_all_portfolio_df = pd.concat([combined_df, my_port_returns_df], axis = 1, join = 'inner')
combined_all_portfolio_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# 2018-05-18                  -0.004357           -0.002672
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
# YOUR CODE HERE
combined_all_portfolio_df_no_nulls = combined_all_portfolio_df.dropna(axis = 0)
combined_all_portfolio_df_no_nulls.isnull().sum(axis = 0)
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P 500                        0
# My Portfolio                   0
# dtype: int64

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
# YOUR CODE HERE
combined_all_port_rolling_std = combined_all_portfolio_df_no_nulls.rolling(window = 21).std().plot(title = '21 Day Rolling Standard Deviation')

# %%
# Rolling
# YOUR CODE HERE

# %%
# Annualized Sharpe Ratios
# YOUR CODE HERE
combined_sharpe_ratios = (combined_all_portfolio_df_no_nulls.mean() * 252) / (combined_all_portfolio_df_no_nulls.std() * np.sqrt(252))
combined_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.430713
# PAULSON & CO.INC.              0.258738
# TIGER GLOBAL MANAGEMENT LLC   -1.034216
# BERKSHIRE HATHAWAY INC         0.159756
# Algo 1                         2.035665
# Algo 2                         0.080607
# S&P 500                        0.584820
# My Portfolio                   0.933123
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# YOUR CODE HERE
combined_sharpe_ratios.plot(kind = 'bar', title = "Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %%
# Create a correlation analysis
# YOUR CODE HERE
all_port_correlation_table = combined_all_portfolio_df_no_nulls.corr()
all_port_correlation_table
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.791962
# PAULSON & CO.INC.                             0.791962            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.478627            0.485375
# BERKSHIRE HATHAWAY INC                        0.816675            0.650758
# Algo 1                                        0.337826            0.361301
# Algo 2                                        0.862846            0.783656
# S&P 500                                       0.876981            0.766680
# My Portfolio                                  0.733250            0.644210
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.478627
# PAULSON & CO.INC.                               0.485375
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.325457
# ...

# %%
sns.heatmap(all_port_correlation_table, vmin = -1, vmax = 1)
# Out:
# <AxesSubplot:>

# %%
# Beta
# YOUR CODE HERE
covariance2 = combined_all_portfolio_df_no_nulls['My Portfolio'].cov(combined_all_portfolio_df_no_nulls['S&P 500'])
variance2 = combined_df['S&P 500'].var()
my_port_beta = covariance2 / variance2
rolling_covariance2 = combined_all_portfolio_df_no_nulls['My Portfolio'].rolling(window = 30).cov(combined_all_portfolio_df_no_nulls['S&P 500'])
rolling_variance2 = combined_all_portfolio_df_no_nulls['S&P 500'].rolling(window = 30).var()

rolling_beta_my_portfolio = rolling_covariance / rolling_variance
rolling_beta_my_portfolio.plot(title = 'Rolling 30 Day Beta of My Portfolio')
#ovariance.plot(figsize=(20,10), title = 'Berkshire Hathaway Inc. Beta')
# Out:
# <AxesSubplot:title={'center':'Rolling 30 Day Beta of My Portfolio'}, xlabel='Date'>
